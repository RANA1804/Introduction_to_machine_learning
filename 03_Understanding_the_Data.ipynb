# %% [markdown]
# <a href="https://colab.research.google.com/github/RANA1804/Introduction_to_machine_learning/blob/main/03_Understanding_the_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Understanding the Data
#
# Exploring and comprehending your data is a fundamental step in the data analysis process. Python, equipped with diverse libraries, offers robust tools for this purpose. Through efficient data exploration, you gain valuable insights into your dataset, paving the way for informed decision-making and further analysis. From loading and summarizing data with pandas to visualizing patterns with Matplotlib and Seaborn, Python facilitates a comprehensive understanding of the data landscape. This initial understanding sets the stage for subsequent tasks, such as handling missing values, transforming features, and conducting statistical analyses, ensuring a solid foundation for meaningful data-driven insights.

# %% [markdown]
# ## Import required Libraries

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# ## Read the Data
# ### Encoding Error
# Character encoding is crucial when dealing with text data, as it defines the mapping between textual characters and the binary representations used by computers. The most common character encodings include UTF-8, UTF-16, and ISO-8859-1, among others.
#
# When you read data into a pandas DataFrame from an external source, such as a CSV file, you might encounter different character encodings. In such cases, you can use the encoding parameter of pandas' read_csv() function to specify the encoding of the file.

# %%
csv_path = r"/content/drive/MyDrive/1.ML/datasets/Global YouTube Statistics.csv"
# df = pd.read_csv(csv_path) # This will give a error because there is a encoding problem
df = pd.read_csv(csv_path, encoding = "latin-1")
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# 1    Film & Animation               youtubemovies        1   United States
# 2       Entertainment                     MrBeast      741   United States
# 3           Education  Cocomelon - Nursery Rhymes      966   United States
# 4               Shows                   SET India   116536           India
# ..                ...                         ...      ...             ...
# 990            Sports               Natan por Aï¿     1200          Brazil
# 991    People & Blogs    Free Fire India Official     1500           India
# 992               NaN                 HybridPanda     2452  United Kingdom
# 993            Gaming                 RobTopGames       39          Sweden
# 994            Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                     2000000.0
# 1             US          Games  ...                           NaN
# 2             US  Entertainment  ...                     8000000.0
# 3             US      Education  ...                     1000000.0
# 4             IN  Entertainment  ...                     1000000.0
# ..           ...            ...  ...                           ...
# 990           BR  Entertainment  ...                      700000.0
# 991           IN          Games  ...                      300000.0
# 992           GB          Games  ...                        1000.0
# 993           SE          Games  ...                      100000.0
# 994           IN         Comedy  ...                      100000.0
#
#      created_year  created_month  created_date  \
# 0          2006.0            Mar          13.0
# 1          2006.0            Mar           5.0
# 2          2012.0            Feb          20.0
# 3          2006.0            Sep           1.0
# 4          2006.0            Sep          20.0
# ..            ...            ...           ...
# 990        2017.0            Feb          12.0
# 991        2018.0            Sep          14.0
# 992        2006.0            Sep          11.0
# 993        2012.0            May           9.0
# 994        2017.0            Aug           1.0
#
#      Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                       28.1  1.366418e+09               5.36
# 1                                       88.2  3.282395e+08              14.70
# 2                                       88.2  3.282395e+08              14.70
# 3                                       88.2  3.282395e+08              14.70
# 4                                       28.1  1.366418e+09               5.36
# ..                                       ...           ...                ...
# 990                                     51.3  2.125594e+08              12.08
# 991                                     28.1  1.366418e+09               5.36
# 992                                     60.0  6.683440e+07               3.85
# 993                                     67.0  1.028545e+07               6.48
# 994                                     28.1  1.366418e+09               5.36
#
#      Urban_population   Latitude  Longitude
# 0         471031528.0  20.593684  78.962880
# 1         270663028.0  37.090240 -95.712891
# 2         270663028.0  37.090240 -95.712891
# 3         270663028.0  37.090240 -95.712891
# 4         471031528.0  20.593684  78.962880
# ..                ...        ...        ...
# 990       183241641.0 -14.235004 -51.925280
# 991       471031528.0  20.593684  78.962880
# 992        55908316.0  55.378051  -3.435973
# 993         9021165.0  60.128161  18.643501
# 994       471031528.0  20.593684  78.962880
#
# [995 rows x 28 columns]

# %% [markdown]
# ## How big is the data?

# %%
df.shape #in this case shape is a attribute of the class of df or dataframe.
# Out:
# (995, 28)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Pandas has two classes:- dataframe and datatypes.

# %% [markdown]
# ## How does the data look like?

# %%
df.head() #Bydefoult it shows the 5 rowws.
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
#
#    Urban_population   Latitude  Longitude
# 0       471031528.0  20.593684  78.962880
# 1       270663028.0  37.090240 -95.712891
# 2       270663028.0  37.090240 -95.712891
# 3       270663028.0  37.090240 -95.712891
# 4       471031528.0  20.593684  78.962880
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Rendomly selecting the rows

# %%
df.sample(5)
# Out:
#      rank           Youtuber  subscribers   video views        category  \
# 233   234        Las Ratitas     25200000  9.602247e+09  People & Blogs
# 796   797       Luli Pampï¿½     14000000  8.623705e+09           Music
# 797   798  Gallina Pintadita     14000000  9.660951e+09           Music
# 82     83  WorkpointOfficial     39000000  3.613123e+10   Entertainment
# 496   497   Jane ASMR ï¿½ï¿½     17700000  7.387622e+09             NaN
#
#                  Title  uploads      Country Abbreviation   channel_type  ...  \
# 233        LAS RATITAS        4          NaN          NaN         People  ...
# 796       Luli Pampï¿½      294        Spain           ES          Music  ...
# 797  Gallina Pintadita       62       Mexico           MX           Film  ...
# 82   WorkpointOfficial    72580     Thailand           TH  Entertainment  ...
# 496   Jane ASMR ï¿½ï¿½     1888  South Korea           KR         People  ...
#
#      subscribers_for_last_30_days  created_year  created_month  created_date  \
# 233                           NaN        2019.0            May          31.0
# 796                      100000.0        2012.0            Dec          22.0
# 797                           NaN        2011.0            Aug           2.0
# 82                       200000.0        2012.0            Nov           5.0
# 496                           NaN        2012.0            Nov          17.0
#
#      Gross tertiary education enrollment (%)   Population  Unemployment rate  \
# 233                                      NaN          NaN                NaN
# 796                                     88.9   47076781.0              13.96
# 797                                     40.2  126014024.0               3.42
# 82                                      49.3   69625582.0               0.75
# 496                                     94.3   51709098.0               4.15
#
#      Urban_population   Latitude   Longitude
# 233               NaN        NaN         NaN
# 796        37927409.0  40.463667   -3.749220
# 797       102626859.0  23.634501 -102.552784
# 82         35294600.0  15.870032  100.992541
# 496        42106719.0  35.907757  127.766922
#
# [5 rows x 28 columns]

# %% [markdown]
# ## What are the datatype of the collumns?

# %%
df.info() # This is a function
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
#  10  video_views_rank                         994 non-null    float64
#  11  country_rank                             879 non-null    float64
#  12  channel_type_rank                        962 non-null    float64
#  13  video_views_for_the_last_30_days         939 non-null    float64
#  14  lowest_monthly_earnings                  995 non-null    float64
#  15  highest_monthly_earnings                 995 non-null    float64
#  16  lowest_yearly_earnings                   995 non-null    float64
#  17  highest_yearly_earnings                  995 non-null    float64
#  18  subscribers_for_last_30_days             658 non-null    float64
#  19  created_year                             990 non-null    float64
#  20  created_month                            990 non-null    object
#  21  created_date                             990 non-null    float64
#  22  Gross tertiary education enrollment (%)  872 non-null    float64
#  23  Population                               872 non-null    float64
#  24  Unemployment rate                        872 non-null    float64
#  25  Urban_population                         872 non-null    float64
#  26  Latitude                                 872 non-null    float64
#  27  Longitude                                872 non-null    float64
# dtypes: float64(18), int64(3), object(7)
# memory usage: 217.8+ KB

# %% [markdown]
# ## Are there any null  values?

# %%
df.isnull()  # If there is any nul values then the results will be "True".
# Out:
#       rank  Youtuber  subscribers  video views  category  Title  uploads  \
# 0    False     False        False        False     False  False    False
# 1    False     False        False        False     False  False    False
# 2    False     False        False        False     False  False    False
# 3    False     False        False        False     False  False    False
# 4    False     False        False        False     False  False    False
# ..     ...       ...          ...          ...       ...    ...      ...
# 990  False     False        False        False     False  False    False
# 991  False     False        False        False     False  False    False
# 992  False     False        False        False      True  False    False
# 993  False     False        False        False     False  False    False
# 994  False     False        False        False     False  False    False
#
#      Country  Abbreviation  channel_type  ...  subscribers_for_last_30_days  \
# 0      False         False         False  ...                         False
# 1      False         False         False  ...                          True
# 2      False         False         False  ...                         False
# 3      False         False         False  ...                         False
# 4      False         False         False  ...                         False
# ..       ...           ...           ...  ...                           ...
# 990    False         False         False  ...                         False
# 991    False         False         False  ...                         False
# 992    False         False         False  ...                         False
# 993    False         False         False  ...                         False
# 994    False         False         False  ...                         False
#
#      created_year  created_month  created_date  \
# 0           False          False         False
# 1           False          False         False
# 2           False          False         False
# 3           False          False         False
# 4           False          False         False
# ..            ...            ...           ...
# 990         False          False         False
# 991         False          False         False
# 992         False          False         False
# 993         False          False         False
# 994         False          False         False
#
#      Gross tertiary education enrollment (%)  Population  Unemployment rate  \
# 0                                      False       False              False
# 1                                      False       False              False
# 2                                      False       False              False
# 3                                      False       False              False
# 4                                      False       False              False
# ..                                       ...         ...                ...
# 990                                    False       False              False
# 991                                    False       False              False
# 992                                    False       False              False
# 993                                    False       False              False
# 994                                    False       False              False
#
#      Urban_population  Latitude  Longitude
# 0               False     False      False
# 1               False     False      False
# 2               False     False      False
# 3               False     False      False
# 4               False     False      False
# ..                ...       ...        ...
# 990             False     False      False
# 991             False     False      False
# 992             False     False      False
# 993             False     False      False
# 994             False     False      False
#
# [995 rows x 28 columns]

# %% [markdown]
# How many null values are existing in a collumn?

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# created_month                                5
# created_date                                 5
# Gross tertiary education enrollment (%)    123
# Population                                 123
# Unemployment rate                          123
# Urban_population                           123
# Latitude                                   123
# Longitude                                  123
# dtype: int64

# %% [markdown]
# ## How does the data lock mathematically?

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# std     1232.244746        1944.386561                      4.163782e+08
# min        1.000000           1.000000                      1.000000e+00
# 25%       11.000000          27.000000                      2.013750e+07
# 50%       51.000000          65.500000                      6.408500e+07
# 75%      123.000000         139.750000                      1.688265e+08
# max     7741.000000        7741.000000                      6.589000e+09
#
#        lowest_monthly_earnings  highest_monthly_earnings  ...  \
# count               995.000000              9.950000e+02  ...
# mean              36886.148281              5.898078e+05  ...
# std               71858.724092              1.148622e+06  ...
# min                   0.000000              0.000000e+00  ...
# 25%                2700.000000              4.350000e+04  ...
# 50%               13300.000000              2.127000e+05  ...
# 75%               37900.000000              6.068000e+05  ...
# max              850900.000000              1.360000e+07  ...
#
#        highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# count             9.950000e+02                  6.580000e+02    990.000000
# mean              7.081814e+06                  3.490791e+05   2012.630303
# std               1.379704e+07                  6.143554e+05      4.512503
# min               0.000000e+00                  1.000000e+00   1970.000000
# 25%               5.217500e+05                  1.000000e+05   2009.000000
# 50%               2.600000e+06                  2.000000e+05   2013.000000
# 75%               7.300000e+06                  4.000000e+05   2016.000000
# max               1.634000e+08                  8.000000e+06   2022.000000
#
#        created_date  Gross tertiary education enrollment (%)    Population  \
# count    990.000000                               872.000000  8.720000e+02
# mean      15.746465                                63.627752  4.303873e+08
# std        8.777520                                26.106893  4.727947e+08
# min        1.000000                                 7.600000  2.025060e+05
# 25%        8.000000                                36.300000  8.335541e+07
# 50%       16.000000                                68.000000  3.282395e+08
# 75%       23.000000                                88.200000  3.282395e+08
# max       31.000000                               113.100000  1.397715e+09
#
#        Unemployment rate  Urban_population    Latitude   Longitude
# count         872.000000      8.720000e+02  872.000000  872.000000
# mean            9.279278      2.242150e+08   26.632783  -14.128146
# std             4.888354      1.546874e+08   20.560533   84.760809
# min             0.750000      3.558800e+04  -38.416097 -172.104629
# 25%             5.270000      5.590832e+07   20.593684  -95.712891
# 50%             9.365000      2.706630e+08   37.090240  -51.925280
# 75%            14.700000      2.706630e+08   37.090240   78.962880
# max            14.720000      8.429340e+08   61.924110  138.252924
#
# [8 rows x 21 columns]

# %% [markdown]
# ## Are there any duplicated rows?

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# Length: 995, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## How is tthe correlation between the columns?
# The df.corr() function in pandas is used to calculate the correlation matrix for a DataFrame. The correlation matrix is a table showing correlation coefficients between variables. These coefficients quantify the degree to which two variables are linearly related.

# %%
# Extract the correlation between all the veriables
df.corr()
# Out:
# <ipython-input-59-932a445c8229>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                              rank  subscribers  video views  \
# rank                                     1.000000    -0.640608    -0.453363
# subscribers                             -0.640608     1.000000     0.750958
# video views                             -0.453363     0.750958     1.000000
# uploads                                 -0.051036     0.077136     0.165928
# video_views_rank                        -0.059455     0.057202    -0.061807
# country_rank                             0.016776     0.032683    -0.068277
# channel_type_rank                       -0.029554     0.027393    -0.050194
# video_views_for_the_last_30_days        -0.186339     0.278846     0.361856
# lowest_monthly_earnings                 -0.248394     0.388941     0.552096
# highest_monthly_earnings                -0.248050     0.388579     0.551455
# lowest_yearly_earnings                  -0.248593     0.389072     0.552776
# highest_yearly_earnings                 -0.248392     0.388935     0.552091
# subscribers_for_last_30_days            -0.188571     0.309527     0.187384
# created_year                             0.106025    -0.141827    -0.127068
# created_date                            -0.006256    -0.011836    -0.038180
# Gross tertiary education enrollment (%) -0.037491    -0.006804    -0.015232
# Population                              -0.025475     0.082219     0.080214
# Unemployment rate                       -0.014860    -0.008251    -0.000729
# Urban_population                        -0.038807     0.083521     0.076649
# Latitude                                 0.000036     0.019450     0.037334
# Longitude                                0.019003     0.022443     0.031268
#
#                                           uploads  video_views_rank  \
# rank                                    -0.051036         -0.059455
# subscribers                              0.077136          0.057202
# video views                              0.165928         -0.061807
# uploads                                  1.000000         -0.108988
# video_views_rank                        -0.108988          1.000000
# country_rank                            -0.078394          0.877504
# channel_type_rank                       -0.098450          0.949936
# video_views_for_the_last_30_days         0.101521         -0.067193
# lowest_monthly_earnings                  0.166922         -0.208863
# highest_monthly_earnings                 0.167283         -0.208935
# lowest_yearly_earnings                   0.167745         -0.208950
# highest_yearly_earnings                  0.166904         -0.208851
# subscribers_for_last_30_days             0.008933         -0.167295
# created_year                            -0.154904          0.006671
# created_date                             0.034900          0.031231
# Gross tertiary education enrollment (%) -0.218396          0.046934
# Population                               0.143122         -0.103178
# Unemployment rate                       -0.188101         -0.029276
# Urban_population                         0.072807         -0.122747
# Latitude                                -0.067868          0.015932
# Longitude                                0.233169         -0.016492
#
#                                          country_rank  channel_type_rank  \
# rank                                         0.016776          -0.029554
# subscribers                                  0.032683           0.027393
# video views                                 -0.068277          -0.050194
# uploads                                     -0.078394          -0.098450
# video_views_rank                             0.877504           0.949936
# country_rank                                 1.000000           0.898442
# channel_type_rank                            0.898442           1.000000
# video_views_for_the_last_30_days            -0.098737          -0.129051
# lowest_monthly_earnings                     -0.148947          -0.187908
# highest_monthly_earnings                    -0.148960          -0.187970
# lowest_yearly_earnings                      -0.149020          -0.187993
# highest_yearly_earnings                     -0.148946          -0.187896
# subscribers_for_last_30_days                -0.126175          -0.154021
# created_year                                -0.037807          -0.014002
# created_date                                -0.012699           0.038299
# Gross tertiary education enrollment (%)      0.103290           0.062484
# Population                                  -0.053181          -0.116254
# Unemployment rate                            0.066697           0.003697
# Urban_population                            -0.024578          -0.123852
# Latitude                                     0.048323           0.010195
# Longitude                                   -0.072476          -0.055144
#
#                                          video_views_for_the_last_30_days  \
# rank                                                            -0.186339
# subscribers                                                      0.278846
# video views                                                      0.361856
# uploads                                                          0.101521
# video_views_rank                                                -0.067193
# country_rank                                                    -0.098737
# channel_type_rank                                               -0.129051
# video_views_for_the_last_30_days                                 1.000000
# lowest_monthly_earnings                                          0.680330
# highest_monthly_earnings                                         0.680289
# lowest_yearly_earnings                                           0.680278
# highest_yearly_earnings                                          0.680330
# subscribers_for_last_30_days                                     0.451523
# created_year                                                     0.053123
# created_date                                                    -0.013670
# Gross tertiary education enrollment (%)                         -0.035610
# Population                                                       0.053859
# Unemployment rate                                               -0.002323
# Urban_population                                                 0.051126
# Latitude                                                        -0.026864
# Longitude                                                        0.049033
#
#                                          lowest_monthly_earnings  \
# rank                                                   -0.248394
# subscribers                                             0.388941
# video views                                             0.552096
# uploads                                                 0.166922
# video_views_rank                                       -0.208863
# country_rank                                           -0.148947
# channel_type_rank                                      -0.187908
# video_views_for_the_last_30_days                        0.680330
# lowest_monthly_earnings                                 1.000000
# highest_monthly_earnings                                0.999955
# lowest_yearly_earnings                                  0.999942
# highest_yearly_earnings                                 0.999998
# subscribers_for_last_30_days                            0.679360
# created_year                                            0.072316
# created_date                                           -0.040269
# Gross tertiary education enrollment (%)                -0.062190
# Population                                              0.104812
# Unemployment rate                                      -0.042874
# Urban_population                                        0.081206
# Latitude                                                0.006583
# Longitude                                               0.100379
#
#                                          highest_monthly_earnings  ...  \
# rank                                                    -0.248050  ...
# subscribers                                              0.388579  ...
# video views                                              0.551455  ...
# uploads                                                  0.167283  ...
# video_views_rank                                        -0.208935  ...
# country_rank                                            -0.148960  ...
# channel_type_rank                                       -0.187970  ...
# video_views_for_the_last_30_days                         0.680289  ...
# lowest_monthly_earnings                                  0.999955  ...
# highest_monthly_earnings                                 1.000000  ...
# lowest_yearly_earnings                                   0.999884  ...
# highest_yearly_earnings                                  0.999953  ...
# subscribers_for_last_30_days                             0.679699  ...
# created_year                                             0.072289  ...
# created_date                                            -0.039959  ...
# Gross tertiary education enrollment (%)                 -0.061973  ...
# Population                                               0.104785  ...
# Unemployment rate                                       -0.042627  ...
# Urban_population                                         0.081226  ...
# Latitude                                                 0.006873  ...
# Longitude                                                0.100299  ...
#
#                                          highest_yearly_earnings  \
# rank                                                   -0.248392
# subscribers                                             0.388935
# video views                                             0.552091
# uploads                                                 0.166904
# video_views_rank                                       -0.208851
# country_rank                                           -0.148946
# channel_type_rank                                      -0.187896
# video_views_for_the_last_30_days                        0.680330
# lowest_monthly_earnings                                 0.999998
# highest_monthly_earnings                                0.999953
# lowest_yearly_earnings                                  0.999941
# highest_yearly_earnings                                 1.000000
# subscribers_for_last_30_days                            0.679380
# created_year                                            0.072263
# created_date                                           -0.040250
# Gross tertiary education enrollment (%)                -0.062163
# Population                                              0.104783
# Unemployment rate                                      -0.042860
# Urban_population                                        0.081165
# Latitude                                                0.006532
# Longitude                                               0.100376
#
#                                          subscribers_for_last_30_days  \
# rank                                                        -0.188571
# subscribers                                                  0.309527
# video views                                                  0.187384
# uploads                                                      0.008933
# video_views_rank                                            -0.167295
# country_rank                                                -0.126175
# channel_type_rank                                           -0.154021
# video_views_for_the_last_30_days                             0.451523
# lowest_monthly_earnings                                      0.679360
# highest_monthly_earnings                                     0.679699
# lowest_yearly_earnings                                       0.678394
# highest_yearly_earnings                                      0.679380
# subscribers_for_last_30_days                                 1.000000
# created_year                                                 0.152117
# created_date                                                 0.006792
# Gross tertiary education enrollment (%)                     -0.020294
# Population                                                   0.038737
# Unemployment rate                                           -0.021130
# Urban_population                                             0.030968
# Latitude                                                    -0.011655
# Longitude                                                    0.072032
#
#                                          created_year  created_date  \
# rank                                         0.106025     -0.006256
# subscribers                                 -0.141827     -0.011836
# video views                                 -0.127068     -0.038180
# uploads                                     -0.154904      0.034900
# video_views_rank                             0.006671      0.031231
# country_rank                                -0.037807     -0.012699
# channel_type_rank                           -0.014002      0.038299
# video_views_for_the_last_30_days             0.053123     -0.013670
# lowest_monthly_earnings                      0.072316     -0.040269
# highest_monthly_earnings                     0.072289     -0.039959
# lowest_yearly_earnings                       0.071911     -0.040047
# highest_yearly_earnings                      0.072263     -0.040250
# subscribers_for_last_30_days                 0.152117      0.006792
# created_year                                 1.000000      0.018641
# created_date                                 0.018641      1.000000
# Gross tertiary education enrollment (%)     -0.162160     -0.087068
# Population                                   0.119630      0.024012
# Unemployment rate                           -0.134943     -0.033133
# Urban_population                             0.074276      0.012260
# Latitude                                    -0.111889      0.020419
# Longitude                                    0.167206      0.026401
#
#                                          Gross tertiary education enrollment (%)  \
# rank                                                                   -0.037491
# subscribers                                                            -0.006804
# video views                                                            -0.015232
# uploads                                                                -0.218396
# video_views_rank                                                        0.046934
# country_rank                                                            0.103290
# channel_type_rank                                                       0.062484
# video_views_for_the_last_30_days                                       -0.035610
# lowest_monthly_earnings                                                -0.062190
# highest_monthly_earnings                                               -0.061973
# lowest_yearly_earnings                                                 -0.062553
# highest_yearly_earnings                                                -0.062163
# subscribers_for_last_30_days                                           -0.020294
# created_year                                                           -0.162160
# created_date                                                           -0.087068
# Gross tertiary education enrollment (%)                                 1.000000
# Population                                                             -0.573302
# Unemployment rate                                                       0.670979
# Urban_population                                                       -0.299787
# Latitude                                                                0.338324
# Longitude                                                              -0.599461
#
#                                          Population  Unemployment rate  \
# rank                                      -0.025475          -0.014860
# subscribers                                0.082219          -0.008251
# video views                                0.080214          -0.000729
# uploads                                    0.143122          -0.188101
# video_views_rank                          -0.103178          -0.029276
# country_rank                              -0.053181           0.066697
# channel_type_rank                         -0.116254           0.003697
# video_views_for_the_last_30_days           0.053859          -0.002323
# lowest_monthly_earnings                    0.104812          -0.042874
# highest_monthly_earnings                   0.104785          -0.042627
# lowest_yearly_earnings                     0.104693          -0.043045
# highest_yearly_earnings                    0.104783          -0.042860
# subscribers_for_last_30_days               0.038737          -0.021130
# created_year                               0.119630          -0.134943
# created_date                               0.024012          -0.033133
# Gross tertiary education enrollment (%)   -0.573302           0.670979
# Population                                 1.000000          -0.217695
# Unemployment rate                         -0.217695           1.000000
# Urban_population                           0.909440           0.142211
# Latitude                                  -0.107974           0.140594
# Longitude                                  0.409426          -0.763279
#
#                                          Urban_population  Latitude  Longitude
# rank                                            -0.038807  0.000036   0.019003
# subscribers                                      0.083521  0.019450   0.022443
# video views                                      0.076649  0.037334   0.031268
# uploads                                          0.072807 -0.067868   0.233169
# video_views_rank                                -0.122747  0.015932  -0.016492
# country_rank                                    -0.024578  0.048323  -0.072476
# channel_type_rank                               -0.123852  0.010195  -0.055144
# video_views_for_the_last_30_days                 0.051126 -0.026864   0.049033
# lowest_monthly_earnings                          0.081206  0.006583   0.100379
# highest_monthly_earnings                         0.081226  0.006873   0.100299
# lowest_yearly_earnings                           0.081025  0.006691   0.100485
# highest_yearly_earnings                          0.081165  0.006532   0.100376
# subscribers_for_last_30_days                     0.030968 -0.011655   0.072032
# created_year                                     0.074276 -0.111889   0.167206
# created_date                                     0.012260  0.020419   0.026401
# Gross tertiary education enrollment (%)         -0.299787  0.338324  -0.599461
# Population                                       0.909440 -0.107974   0.409426
# Unemployment rate                                0.142211  0.140594  -0.763279
# Urban_population                                 1.000000 -0.020815   0.088956
# Latitude                                        -0.020815  1.000000  -0.200219
# Longitude                                        0.088956 -0.200219   1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# ## Correlation of a perticular column with all the columns

# %%
df.corr()["subscribers"]
# Out:
# <ipython-input-60-554f1d748278>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["subscribers"]
# rank                                      -0.640608
# subscribers                                1.000000
# video views                                0.750958
# uploads                                    0.077136
# video_views_rank                           0.057202
# country_rank                               0.032683
# channel_type_rank                          0.027393
# video_views_for_the_last_30_days           0.278846
# lowest_monthly_earnings                    0.388941
# highest_monthly_earnings                   0.388579
# lowest_yearly_earnings                     0.389072
# highest_yearly_earnings                    0.388935
# subscribers_for_last_30_days               0.309527
# created_year                              -0.141827
# created_date                              -0.011836
# Gross tertiary education enrollment (%)   -0.006804
# Population                                 0.082219
# Unemployment rate                         -0.008251
# Urban_population                           0.083521
# Latitude                                   0.019450
# Longitude                                  0.022443
# Name: subscribers, dtype: float64

# %% [markdown]
# ## Creation of a DataqFrame and calculation of correlation matrix

# %%
data = {"a" : [2,4,6,5],
        "b" : [2,4,7,8],
        "c" : [5,4,5,7]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    a  b  c
# 0  2  2  5
# 1  4  4  4
# 2  6  7  5
# 3  5  8  7

# %%
column_matrix = df.corr()
column_matrix
# Out:
#           a         b         c
# a  1.000000  0.903682  0.271448
# b  0.903682  1.000000  0.649331
# c  0.271448  0.649331  1.000000

# %%
df.corr()["a"]
# Out:
# a    1.000000
# b    0.903682
# c    0.271448
# Name: a, dtype: float64
